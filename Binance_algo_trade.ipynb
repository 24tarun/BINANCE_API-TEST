# %%
from binance import Client
import pandas as pd

# %%
api_key='FlA5fSAYb1HHk5ozWNDaljsIot0p0mVlxRgWtOF5kmvJmzt5gRZ1mePKbskadY6U'
api_secret='spD9RxuIgl6NTwUFFED7jjXgLIMap1s1akywuUgEWFien7LjkmhF7Fr37lRVNlxj'
client = Client(api_key, api_secret)
client.get_account()

# %%
#say for multiple api keys
#get api_key and secret into a list and parse through
api_key=['FlA5fSAYb1HHk5ozWNDaljsIot0p0mVlxRgWtOF5kmvJmzt5gRZ1mePKbskadY6U','api2','api3','andso_on']
api_secret=['spD9RxuIgl6NTwUFFED7jjXgLIMap1s1akywuUgEWFien7LjkmhF7Fr37lRVNlxj','apis2','apis3','andso_on']
apipairs= len(api_key)
for i in range(apipairs):
    client = Client(api_key[i], api_secret[i])
client.get_account()
# Out:
# 4
# {'makerCommission': 10,
#  'takerCommission': 10,
#  'buyerCommission': 0,
#  'sellerCommission': 0,
#  'canTrade': True,
#  'canWithdraw': True,
#  'canDeposit': True,
#  'updateTime': 1644508976913,
#  'accountType': 'SPOT',
#  'balances': [{'asset': 'BTC', 'free': '0.00331017', 'locked': '0.00000000'},
#   {'asset': 'LTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETH', 'free': '0.00970000', 'locked': '0.00000000'},
#   {'asset': 'NEO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNB', 'free': '0.00414979', 'locked': '0.00000000'},
#   {'asset': 'QTUM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GAS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCC', 'free': '0.00000000', 'locked': '0.00000000'},
# ...

# %%
def getminutedata(symbol,interval,lookback):
    frame = pd.DataFrame(client.get_historical_klines(symbol,interval,lookback+"min ago UTC"))
    frame=frame.iloc[:,:6]
    frame.columns=['time','open','high','low','close','volume']
    frame=frame.set_index('time')
    frame.index=pd.to_datetime(frame.index,unit='ms')
    frame=frame.astype(float)
    return frame

# %%
getminutedata('BTCUSDT' , '1m' , '30')
# Out:
#                          open      high       low     close    volume
# time
# 2022-05-22 02:54:00  29392.26  29392.27  29392.26  29392.27   1.79211
# 2022-05-22 02:55:00  29392.27  29392.27  29392.26  29392.26   4.08170
# 2022-05-22 02:56:00  29392.26  29408.39  29392.26  29404.74   9.94867
# 2022-05-22 02:57:00  29404.73  29404.74  29400.04  29400.05   6.37721
# 2022-05-22 02:58:00  29400.05  29400.05  29392.26  29392.27  10.13080
# 2022-05-22 02:59:00  29392.27  29400.18  29392.26  29400.17  16.09961
# 2022-05-22 03:00:00  29400.18  29400.18  29379.06  29379.07   9.46679
# 2022-05-22 03:01:00  29379.06  29403.72  29379.05  29401.32  10.62920
# 2022-05-22 03:02:00  29401.31  29404.41  29399.61  29404.40   5.93688
# 2022-05-22 03:03:00  29404.41  29404.41  29404.40  29404.40   7.08991
# 2022-05-22 03:04:00  29404.41  29404.41  29399.46  29399.47  17.71755
# 2022-05-22 03:05:00  29399.46  29399.47  29396.59  29396.61   6.52382
# ...

# %%
#buy if asset falls by 0.2% in last 30 mins
#sell if asset rises by more than 0.15% or stop loss if falls further by 0.15%

def strategytest(symbol,interval,lookback,qty,entried=False):
    df = getminutedata(symbol,interval,lookback)
    cumulret = (df.open.pct_change()+1).cumprod()-1
    if not entried:
        if cumulret[-1] < -0.002:
            order = client.create_order(symbol=symbol,side='BUY', type='MARKET',quantity=qty)
            print(order)
            entried=True
        else:
            print("not traded")
    if entried:
        while True:
            df = getminutedata(symbol,interval,lookback)
            sincebuy = df.loc[df.index>pd.to_datetime(order['transactTime'], unit='ms')]
            if len(sincebuy) >0:
                sincebuyret=(sincebuy.open.pct_change()+1).cumprod()-1
                if sincebuyret[-1]> 0.0015 or sincebuyret[-1] < -0.0015:
                    order = client.create_order(symbol=symbol,side='SELL', type='MARKET',quantity=qty)
                    print(order)
                    break

# %%
#no confirmation order is immediately placed if conditions are met

#strategytest('BTCUSDT','1m','30',0.0001)
